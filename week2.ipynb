# %% [markdown]
# <a href="https://colab.research.google.com/github/deand21/Tugas-2/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # Latihan 1

 tegangan = 18
 arus = 6
 jenis_sel = "Monocrystalline"

 print(tegangan)
 print(arus)
 print(jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
# Latihan 2

capasitor = 60
resistor = 0.6
komponen = "dioda"
saklar = True

print (capasitor,type(capasitor))
print (resistor,type(resistor))
print (komponen,type(komponen))
print (saklar,type(saklar))
# Out:
# 60 <class 'int'>
# 0.6 <class 'float'>
# dioda <class 'str'>
# True <class 'bool'>

# %%
# Latihan 3

Nama_unit = "PLTS Nunukan"
Jumlah_panel = 240
Tegangan_keluaran = 48.5
Sedang_beroperasi = True

print (type(Nama_unit))
print (type(Jumlah_panel))
print (type(Tegangan_keluaran))
print (type(Sedang_beroperasi))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Latihan 4

tegangan_harian = [217.5 , 219.0 , 220.3 , 218.7 , 221.1 , 216.9]

#A
print (tegangan_harian[0])
print (tegangan_harian[5])

#B
tegangan_harian.append(220.0)
print (tegangan_harian)

#C
print (len(tegangan_harian))
# Out:
# 217.5
# 216.9
# [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 220.0]
# 7

# %%
Motor_listrik = {"nama" : "vario" , "daya_Kw" : 40 , "tegangan_V" : 20 , "rpm" : 10}

#A
print (Motor_listrik["nama"])

#B
Motor_listrik ["rpm"] = 42

#C
print (Motor_listrik)
# Out:
# vario
# {'nama': 'vario', 'daya_Kw': 40, 'tegangan_V': 20, 'rpm': 42}

# %%
# Latihan 6

Pembangkit = [{"nama" : "PLTU" , "kapasitas_Mw" : 10 , "status" : "maintanance"},
              {"nama" : "PLTS" , "kapaistas_Mw" : 20 , "status" : "operasi"},
              {"nama" : "PLTN" , "kapasitas_Mw" : 30 , "status" : "pemeliharaan"}]
#A
print (Pembangkit[2]["nama"])


#B
Pembangkit [1]["status"] = "oke"
print (Pembangkit[1]["status"])

#C
Pembangkit.append({"nama" : "PLTG" , "kapasitas_Mw" : 40 , "status" : "baik"})
print (Pembangkit)
# Out:
# PLTN
# oke
# [{'nama': 'PLTU', 'kapasitas_Mw': 10, 'status': 'maintanance'}, {'nama': 'PLTS', 'kapaistas_Mw': 20, 'status': 'oke'}, {'nama': 'PLTN', 'kapasitas_Mw': 30, 'status': 'pemeliharaan'}, {'nama': 'PLTG', 'kapasitas_Mw': 40, 'status': 'baik'}]
